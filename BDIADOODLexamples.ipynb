# %%
# !pip install omegaconf
# !pip install diffusers
# !pip install open_clip_torch

# %%
'''Comented implementation for Google Colab,
adjust to your file path in google drive to run '''
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/MyDrive/BDIA_DOODL')
# %cd /content/drive/MyDrive/BDIA_DOODL

from BDIA_doodl import gen
#from doodl import gen
from PIL import Image
import time
! mkdir ims

'''Example text prompts to run'''
#prompt = 'Darth Vader playing with raccoon on Mars during sunset.'
prompt = 'A kitten'
#prompt = "Two green birds are perched next to a grey bird"
#prompt = "A green bird."
#prompt = "A puppy."
#prompt = "A car"
#prompt = "Two cyclists in a forest."
#prompt = "A black bear in a forest."
#prompt = "A train."
#prompt = "A river at sunrise."
#prompt = "A large black bear standing in a forest."
#prompt = "A dramatic photo from the surface of Mars."
#prompt = 'A sphere made of kitchen tile. A sphere with the texture of kitchen tile.'
#prompt = 'Pink Fluffy Unicorns Dancing On Rainbows.'

seed = 0 #time.time()
gs = 1
gen(prompt,
    model_guidance_type='CLIP',
    model_guidance_dict={'clip_prompt':prompt},
    grad_scale=gs,
    seed=seed,
    latent_seed=seed,
    steps = 50,
    num_traversal_steps=1,
    save_str='clip_text.png',
    )
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/BDIA_DOODL
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loaded all models
# Using torch float16, if need more precision need to change custom_fwd
# mkdir: cannot create directory ‘ims’: File exists
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/904 [00:00<?, ?B/s]
# ...
